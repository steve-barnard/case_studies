# %% [markdown]
# # Credit Risk Analysis
#
# In this nb the intial credit risk data will be cleaned and prepped for furhter analysis. This is a dataset repurposed from the UCI data repository.

# %% [markdown]
# ## Step 0 - Understand the Business Problem
#
# Using demographic and financial data determine if a credit account account (row) will default next month.

# %%
import pandas as pd

# %%
df = pd.read_excel('../../data_sets/default_of_credit_card_clients__courseware_version_1_21_19.xls')

# %% [markdown]
# ## Step 1 - Verify and Review Data

# %%
df.shape # check the shape (rows, columns)
# Out:
# (30000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null object
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_1                         30000 non-null object
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# BILL_AMT6                     30000 non-null int64
# PAY_AMT1                      30000 non-null int64
# PAY_AMT2                      30000 non-null int64
# PAY_AMT3                      30000 non-null int64
# PAY_AMT4                      30000 non-null int64
# PAY_AMT5                      30000 non-null int64
# PAY_AMT6                      30000 non-null int64
# default payment next month    30000 non-null int64
# dtypes: int64(23), object(2)
# memory usage: 5.7+ MB

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    165760.989333      1.586500      1.833333      1.535900     35.108800
# std     130158.590432      0.513348      0.807699      0.542698      9.851592
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.132867     -0.164333     -0.219300     -0.263900     -0.288033
# std        1.191215      1.191096      1.162348      1.127519      1.144981
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   42791.362167   39884.398167   38480.350933    5613.321500
# std    ...   64090.316188   60606.644833   59406.836932   16539.094312
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2034.000000    1534.000000    1080.000000     836.000000
# 50%    ...   18759.500000   17835.500000   16643.000000    2084.500000
# 75%    ...   53572.250000   49804.000000   48863.500000    5000.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2       PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.000000   30000.000000   30000.000000
# mean   5.855410e+03    5174.387967    4776.089733    4754.749200
# std    2.299256e+04   17565.538305   15532.893047   15239.070708
# min    0.000000e+00       0.000000       0.000000       0.000000
# 25%    7.217500e+02     371.000000     223.000000     170.750000
# 50%    2.000000e+03    1776.000000    1500.000000    1500.000000
# 75%    5.000000e+03    4500.000000    4000.000000    4000.000000
# max    1.684259e+06  896040.000000  621000.000000  426529.000000
#
#             PAY_AMT6  default payment next month
# count   30000.000000                30000.000000
# mean     5164.223267                    0.218733
# std     17712.664703                    0.413394
# min         0.000000                    0.000000
# 25%         9.000000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 23 columns]

# %%
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0         0                           1
# 1      1000      1000         0      2000                           1
# 2      1000      1000      1000      5000                           0
# 3      1200      1100      1069      1000                           0
# 4     10000      9000       689       679                           0
#
# [5 rows x 25 columns]

# %%
df.columns #1-6 indicates historical months
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %% [markdown]
# Checkign more on data quality and for duplicate IDs/rows.

# %%
df.nunique()
# Out:
# ID                            29687
# LIMIT_BAL                        82
# SEX                               3
# EDUCATION                         7
# MARRIAGE                          4
# AGE                              57
# PAY_1                            12
# PAY_2                            11
# PAY_3                            11
# PAY_4                            11
# PAY_5                            10
# PAY_6                            10
# BILL_AMT1                     22510
# BILL_AMT2                     22146
# BILL_AMT3                     21822
# BILL_AMT4                     21350
# BILL_AMT5                     20831
# BILL_AMT6                     20417
# PAY_AMT1                       7890
# PAY_AMT2                       7847
# PAY_AMT3                       7463
# PAY_AMT4                       6901
# PAY_AMT5                       6857
# PAY_AMT6                       6895
# default payment next month        2
# dtype: int64

# %%
df['ID'].nunique() # see how the number is not equal to 30k this may be a data quality issue.
# Out:
# 29687

# %%
id_counts = df['ID'].value_counts()
id_counts.value_counts()
# Out:
# 1    29374
# 2      313
# Name: ID, dtype: int64

# %%
dupe_mask = id_counts == 2
dupe_mask[:5]
# Out:
# 1b22b0ab-aba3    True
# fd6033f4-cc72    True
# 91c69d1a-8732    True
# a9ce8636-9a88    True
# 527c11ea-113e    True
# Name: ID, dtype: bool

# %%
dupe_ids = id_counts.index[dupe_mask]
len(dupe_ids)
# Out:
# 313

# %%
dupe_ids[:5]
# Out:
# Index(['1b22b0ab-aba3', 'fd6033f4-cc72', '91c69d1a-8732', 'a9ce8636-9a88',
#        '527c11ea-113e'],
#       dtype='object')

# %%
df.loc[df['ID'].isin(dupe_ids[:5]),:].head(10)
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE          PAY_1  \
# 3757   fd6033f4-cc72     180000    2          1         2   27  Not available
# 3857   fd6033f4-cc72          0    0          0         0    0              0
# 4954   527c11ea-113e     340000    1          1         2   35  Not available
# 5054   527c11ea-113e          0    0          0         0    0              0
# 5374   1b22b0ab-aba3      30000    2          1         2   30              0
# 5474   1b22b0ab-aba3          0    0          0         0    0              0
# 12769  91c69d1a-8732      70000    2          2         2   22              0
# 12869  91c69d1a-8732          0    0          0         0    0              0
# 19672  a9ce8636-9a88      20000    2          2         1   34  Not available
# 19772  a9ce8636-9a88          0    0          0         0    0              0
#
#        PAY_2  PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 3757      -2     -2     -2  ...       -200       -200       -200         0
# 3857       0      0      0  ...          0          0          0         0
# 4954      -1     -1     -1  ...       7569        797       1211      2873
# 5054       0      0      0  ...          0          0          0         0
# 5374       0      0      0  ...      32389      33142      33999      1600
# 5474       0      0      0  ...          0          0          0         0
# 12769     -1      0      0  ...      50716      48862      49850     68209
# 12869      0      0      0  ...          0          0          0         0
# 19672      0      0      0  ...      10926      17536       2090      2000
# 19772      0      0      0  ...          0          0          0         0
#
#        PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 3757          0         0         0         0         0
# 3857          0         0         0         0         0
# 4954          0      7591       799      1214     18309
# 5054          0         0         0         0         0
# 5374       2000      1500      1200      1330      2500
# 5474          0         0         0         0         0
# 12769      2081      2000      2000      1828      1518
# 12869         0         0         0         0         0
# 19672      3000      3000      7000      2090         0
# 19772         0         0         0         0         0
#
#        default payment next month
# 3757                            1
# 3857                            0
# 4954                            0
# 5054                            0
# 5374                            0
# 5474                            0
# 12769                           0
# 12869                           0
# 19672                           0
# 19772                           0
#
# [10 rows x 25 columns]

# %%
df_zero_mask = df == 0  # boolean mask where all locations are 0

# %%
feature_zero_mask = df_zero_mask.iloc[:,1:].all(axis=1) #boolean on rownum where rows 2 to response var are 0.

# %%
sum(feature_zero_mask)
# Out:
# 315

# %%
df_clean_1 = df.loc[~feature_zero_mask, :].copy()

# %%
df_clean_1.shape
# Out:
# (29685, 25)

# %%
df_clean_1.nunique() #df_clean_1['ID'].nunique()
# Out:
# ID                            29685
# LIMIT_BAL                        81
# SEX                               2
# EDUCATION                         7
# MARRIAGE                          4
# AGE                              56
# PAY_1                            12
# PAY_2                            11
# PAY_3                            11
# PAY_4                            11
# PAY_5                            10
# PAY_6                            10
# BILL_AMT1                     22510
# BILL_AMT2                     22146
# BILL_AMT3                     21822
# BILL_AMT4                     21350
# BILL_AMT5                     20831
# BILL_AMT6                     20417
# PAY_AMT1                       7890
# PAY_AMT2                       7847
# PAY_AMT3                       7463
# PAY_AMT4                       6901
# PAY_AMT5                       6857
# PAY_AMT6                       6895
# default payment next month        2
# dtype: int64

# %% [markdown]
# ### Stats:
#
# Rows = 30,000
#
# Columns = 25
#
# Response var = default payment next month  [other data are features]
